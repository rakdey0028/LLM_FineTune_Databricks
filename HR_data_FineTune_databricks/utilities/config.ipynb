# %%
base_model="meta-llama/Meta-Llama-3-8B" #meta-llama/Llama-3.2-1B"
base_model_name=base_model.split("/")[-1]
base_model_name

# %%
non_instruct_max_seq_length=512
instruct_max_seq_length=1024
DPO_max_seq_length=1024

# %%
non_instruction_dataset='/Volumes/workspace/ai_model/ip_data/stage1_non_instruction.txt'
instruction_dataset='/Volumes/workspace/ai_model/ip_data/hr_sft_dataset_full_1000.jsonl'
preference_dataset='/Volumes/workspace/ai_model/ip_data/HR_preference_dataset_cleaned.jsonl'
eval_dataset='/Volumes/workspace/ai_model/ip_data/eval_questions_with_ground_truth.json'

# %%
non_instruction_merged_repo_name="rakdey/HRA-Non-Instruct-Merged"
instruction_merged_repo_name=f"rakdey/{base_model_name}_base_HR-Non-Instruct"
preference_merged_repo_name=f"rakdey/{base_model_name}_base_HR-Preference"

# %%
stage1_merged_path='/Volumes/workspace/ai_model/model_merged/stage1/'
stage2_merged_path='/Volumes/workspace/ai_model/model_merged/stage2/'
stage3_merged_path='/Volumes/workspace/ai_model/model_merged/stage3/'

# %%
stage1_adapter_path='/Volumes/workspace/ai_model/model_adapter/stage1/'
stage2_adapter_path='/Volumes/workspace/ai_model/model_adapter/stage2/'
stage3_adapter_path='/Volumes/workspace/ai_model/model_adapter/stage3/'

# %%
hf_write_token=dbutils.secrets.get(catalog="workspace", schema="ai_model",key="hf_write_token")
